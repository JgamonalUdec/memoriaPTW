# %%
# !python

# %%
# !git clone https://github.com/harryjfowen/PointsToWood.git

# %%
# %cd PointsToWood/pointstowood
# Out:
# /tmp/code/PointsToWood/pointstowood
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python3 predict.py --point-cloud ../data/spa04-lw.ply --model exp1.pth --batch_size 8 --is-wood 0.5 --grid_size 2.0 4.0 --max_pts 16384;

# %%
# %cd PointsToWood/pointstowood

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !python3 train.py --preprocess --num_epochs 6 --test --tune --model global_test.pth --min_pts 128
# Out:
# Mode: train
# True
# read in /tmp/code/PointsToWood/pointstowood/data/train/Tree1_etiq_refl_no_nan_filtered.ply with 346580 points
# Reflectance detected
# Voxelising to [2.0, 4.0] grid sizes
# Height Normalising Point Cloud
# Writing voxels: 100%|███████████████████████| 379/379 [00:00<00:00, 2749.51it/s]
#
# Testing
# read in /tmp/code/PointsToWood/pointstowood/data/test/Tree1_etiq_refl_no_nan_filtered.ply with 346580 points
# Reflectance detected
# Voxelising to [2.0, 4.0] grid sizes
# Height Normalising Point Cloud
# Writing voxels: 100%|███████████████████████| 379/379 [00:00<00:00, 2954.88it/s]
# Model contains 18158852  parameters
# /tmp/code/PointsToWood/pointstowood/data/train/voxels
# TrainingDataset(379)
# Traceback (most recent call last):
#   File "/tmp/code/PointsToWood/pointstowood/train.py", line 162, in <module>
#     SemanticTraining(args)
#   File "/tmp/code/PointsToWood/pointstowood/src/trainer.py", line 130, in SemanticTraining
# ...
